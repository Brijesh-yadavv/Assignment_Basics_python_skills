# %%
1. who developed python programming language??
=> Guido van Rossum developed the Python programming language.

2. Which type of programming does python support?
=> Python supports multiple programming paradigms, including object-oriented,
functional, procedural, and aspect-oriented programming.

3. Is python case sensitive language?
=> Yes, Python is a case-sensitive language.
This means that the distinction between uppercase and lowercase characters is significant
in the language, and the same identifier (variable, function name, etc.)
can have different meanings based on its case.




4. what is correct extension of python file ?
=> The correct file extension for Python source code is ".py". 
This extension is used to indicate that a 
file contains Python code that can be executed on a Python interpreter.


5. Is python code compiled or interpreted?
=> Python code is interpreted, not compiled. This means that the source code is translated into
machine-readable code line by line, at runtime, by the Python interpreter. 
The interpreted code can be executed immediately, making the development and testing process faster,
but also leading to slower performance compared to compiled code.
    

6. Name a few blocks of code used to define in python language?
=> In Python, blocks of code are defined using indentation.
The following are some blocks of code used in Python:

Functions: defined using the def keyword and indented code within.
Classes: defined using the class keyword and indented code within.
Conditional statements: defined using if, elif, and else keywords and indented code within.
Loops: defined using for and while loops and indented code within.
Context managers: defined using with statements and indented code within.
Comprehensions: defined using list comprehensions,
dictionary comprehensions, and generator comprehensions.
These are some common blocks of code in Python, but there are other constructs as well.

7. State a character used to give single-line comments?
=> # 
# This is a single-line comment

8. Mention functions which can help us to find the version of python that we are currently working on?
=> import sys
print(sys.version)

9.Python supports the creation of ananymous function at runtime using a construct called?
=>  "lambda function"

10. What does pip stands for python?
=> "pip" stands for "Pip Installs Packages".

11. Mention a few built-in-function in python?
=> print: used to output values to the console
len: used to get the length of an object (such as a string, list, or tuple)
type: used to determine the type of an object

12. What is the maximum possible length of an indetifier in python?
=> 63 characters
13. What are the benefits of using python?
=> Python is a popular and versatile programming language with a number of benefits, including:

Easy to learn and use: Python has a simple and 
straightforward syntax that is easy to learn, especially for those new to programming.

Versatile: Python can be used for a wide range of tasks, including web development, scientific 
computing, data analysis, machine learning, artificial intelligence, and more.

Large community: Python has a large and active community of developers and users, making it easy 
to find help, resources, and packages to extend its functionality.

Cross-platform compatibility: Python can run on a variety of platforms, including Windows, MacOS, 
and Linux, making it a good choice for cross-platform development.

Large standard library: Python comes with a large standard library that includes many modules and
functions, making it easy to perform common tasks without having to write a lot of code.

Dynamically typed: Python is a dynamically-typed language, meaning that data types are associated with 
values, not variables, making it easier to write flexible and reusable code.

Easy to integrate with other languages: Python can easily be 
integrated with other programming languages, such as C/C++,
allowing you to use existing libraries and tools in your Python projects.





14. How is memory managed in python?
=> In Python, memory management is handled by the Python 
memory manager and the underlying operating system.
The Python memory manager is responsible for allocating
memory to Python objects and data structures and freeing it when it is no longer needed.
This is done automatically through a process known as reference counting, where the memory manager
keeps track of the number of references to an object. 
When the reference count of an object reaches zero,
it is automatically deallocated and the memory it was using is freed.

15. How to install python in windows and set path variable?
=> Here are the steps to install Python on Windows and set the path variable:

Download the latest version of Python from the official website (https://www.python.org/downloads/).

Run the installation file and follow the instructions to install Python.
Make sure to check the option to add Python to the environment 
variables so that you can use it from the command prompt.

Open the Start menu and search for "Environment Variables". 
Click on "Edit the system environment variables".

In the System Properties window, click on the "Environment Variables" button.

In the Environment Variables window, scroll down to the "System variables"
section and find the "Path" variable. Click on "Edit".

In the Edit environment variable window, click on "New" and 
add the path to the Python installation (e.g. C:\Python37\).

Click "OK" to close all windows and save the changes.

Open the Command Prompt and type python to verify that the installation was 
successful and the path variable was set correctly.

With these steps, you should have successfully installed Python on your Windows machine and set
the path variable so that you can use it from the command prompt.




16. Is indentation required in python?
=> Yes
